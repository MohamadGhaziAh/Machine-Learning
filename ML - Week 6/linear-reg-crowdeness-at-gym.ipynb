# %% [markdown]
# # **Linear Regression**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("/kaggle/input/crowdedness-at-the-campus-gym/data.csv")

# %%
df
# Out:
#        number_people                       date  timestamp  day_of_week  \
# 0                 37  2015-08-14 17:00:11-07:00      61211            4
# 1                 45  2015-08-14 17:20:14-07:00      62414            4
# 2                 40  2015-08-14 17:30:15-07:00      63015            4
# 3                 44  2015-08-14 17:40:16-07:00      63616            4
# 4                 45  2015-08-14 17:50:17-07:00      64217            4
# ...              ...                        ...        ...          ...
# 62179             23  2017-03-18 18:42:28-07:00      67348            5
# 62180             21  2017-03-18 18:52:35-07:00      67955            5
# 62181             25  2017-03-18 19:02:40-07:00      68560            5
# 62182             18  2017-03-18 19:12:47-07:00      69167            5
# 62183             23  2017-03-18 19:22:51-07:00      69771            5
#
#        is_weekend  is_holiday  temperature  is_start_of_semester  \
# ...

# %%
df.head()
# Out:
#    number_people                       date  timestamp  day_of_week  \
# 0             37  2015-08-14 17:00:11-07:00      61211            4
# 1             45  2015-08-14 17:20:14-07:00      62414            4
# 2             40  2015-08-14 17:30:15-07:00      63015            4
# 3             44  2015-08-14 17:40:16-07:00      63616            4
# 4             45  2015-08-14 17:50:17-07:00      64217            4
#
#    is_weekend  is_holiday  temperature  is_start_of_semester  \
# 0           0           0        71.76                     0
# 1           0           0        71.76                     0
# 2           0           0        71.76                     0
# 3           0           0        71.76                     0
# 4           0           0        71.76                     0
#
#    is_during_semester  month  hour
# 0                   0      8    17
# 1                   0      8    17
# 2                   0      8    17
# 3                   0      8    17
# ...

# %%
plt.scatter(df.temperature,df.day_of_week) 
plt.xlabel("temperature") 
plt.ylabel("day_of_week")    
plt.show()

# %%
x = df.temperature.values

# %%
x.shape
# Out:
# (62184,)

# %%
x = df.temperature.values.reshape(-1,1)
y = df.day_of_week.values.reshape(-1,1)

# %%
from sklearn.linear_model import LinearRegression

linear_reg = LinearRegression() 
linear_reg.fit(x,y)
# Out:
# LinearRegression()

# %%
#prediction
import numpy as np

b0 = linear_reg.predict([[0]]) 
print("b0: ",b0)
# Out:
# b0:  [[2.77574944]]

# %%
b0_ = linear_reg.intercept_   
print("b0: ",b0_)
# Out:
# b0:  [2.77574944]

# %%
b1 = linear_reg.coef_  
print("b1: ",b1)
# Out:
# b1:  [[0.00353081]]

# %%
b11 = linear_reg.predict([[11]]) 
print("b11: ",b11)
# Out:
# b11:  [[2.81458836]]

# %%
y_head = linear_reg.predict(x)

# %%
plt.plot(x, y_head, color="pink")
plt.scatter(x,y)
plt.show()

# %%
from sklearn.metrics import r2_score
print("R Square Score: ",r2_score(y,y_head))
# Out:
# R Square Score:  0.000124740552578384

# %%
from sklearn.metrics import mean_squared_error
print("Mean Squared Error: ",mean_squared_error(y,y_head))
# Out:
# Mean Squared Error:  3.986749570740113

# %%
MSE = np.square(np.subtract(y,y_head)).mean()
print("Mean Squared Error: ",MSE)
# Out:
# Mean Squared Error:  3.986749570740113
